# %% [markdown]
# # Precificação Inteligente Airbnb
#
# A partir dos dados dos clientes, iremos criar um modelo de machine learning de **precificação inteligente, onde, baseado nas características dos imóveis, nosso modelo irá sugerir um preço automaticamente**. Isso agrega bastante valor, pois, o cliente pode utilizar o modelo para fazer sua precificação de forma rápida e alinhada ao mercado, já que o modelo será treinado com os dados de outros clientes. Esse problema de negócio, pode ser usado em diversos mercados diferentes, como por exemplo precificação de produtos no atacado e varejo.
#
# <img src="https://img.freepik.com/vetores-gratis/os-funcionarios-do-departamento-financeiro-estao-calculando-as-despesas-dos-negocios-da-empresa_1150-41782.jpg?w=740&t=st=1659997600~exp=1659998200~hmac=18a8593ddb566559e2bb87a1d54ffce6d5719471875595b2195a5e15d45973bc" width="30%">

# %% [markdown]
# ## Coleta dos dados
#
# Os [dados](http://insideairbnb.com/get-the-data/) foram coletados do próprio Airbnb. Confere lá!

# %%
# Importar os pacotes necessários
import warnings
warnings.simplefilter(action='ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Código que transforma o csv em um dataframe pandas
df = pd.read_csv('listings.csv.gz')

# %% [markdown]
# ### Uma rápida olhada na estrutura dos dados

# %%
# Verificar as 5 primeiras linhas do conjunto de dados
pd.set_option("display.max_columns", None)
df.head()
# Out:
#                    id                                      listing_url  \
# 0            15965441            https://www.airbnb.com/rooms/15965441
# 1            47908784            https://www.airbnb.com/rooms/47908784
# 2            52239613            https://www.airbnb.com/rooms/52239613
# 3            10445855            https://www.airbnb.com/rooms/10445855
# 4  565405043878669885  https://www.airbnb.com/rooms/565405043878669885
#
#         scrape_id last_scraped  \
# 0  20220620202144   2022-06-20
# 1  20220620202144   2022-06-20
# 2  20220620202144   2022-06-20
# 3  20220620202144   2022-06-20
# 4  20220620202144   2022-06-20
#
#                                                 name  \
# 0  Quarto de casal com vista para a Baía de Guana...
# 1     Apartamento bem localizado, bonito e familiar!
# 2              Apartamento com varanda e linda vista
# 3                         Campo dos Afonsos, Sulacap
# 4    Pousada completa: 2 quartos com muita natureza!
#
#                                          description  \
# 0  Meu espaço é bom para casais, aventuras indivi...
# 1                                                NaN
# 2  Condomínio com porteiro 24 horas , piscina, sa...
# 3  Casa com vista para as instalações do Parque  ...
# 4  Este lugar único e cheio de estilo é o cenário...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  O condomínio fica em frente ao portão 2 do PRO...
# 3  Bairro suburbano, tranquilo, seguro, casas bem...
# 4                                                NaN
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/76550464-7859...  103691209
# 1  https://a0.muscache.com/pictures/f44537ff-72f1...   83985216
# 2  https://a0.muscache.com/pictures/miso/Hosting-...  422870631
# 3  https://a0.muscache.com/pictures/0f42e026-0955...    1647571
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   24596747
#
#                                       host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/103691209      José  2016-11-14
# 1   https://www.airbnb.com/users/show/83985216    Raquel  2016-07-15
# 2  https://www.airbnb.com/users/show/422870631     Fabio  2021-09-13
# 3    https://www.airbnb.com/users/show/1647571    Márcio  2012-01-24
# 4   https://www.airbnb.com/users/show/24596747     Júlio  2014-12-07
#
#                                      host_location  \
# 0  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2      Petrópolis, State of Rio de Janeiro, Brazil
# 3  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4  Rio de Janeiro, State of Rio de Janeiro, Brazil
#
#                                           host_about host_response_time  \
# 0                                                NaN     within an hour
# 1                                                NaN       within a day
# 2                                                NaN       within a day
# 3  Agora trabalhando com Experiencias do AirBnB. =-)     within an hour
# 4  Sou  músico, professor, empreendedor, fotógraf...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                83%                   0%                 f
# 1                50%                 100%                 f
# 2               100%                  89%                 f
# 3               100%                 100%                 f
# 4               100%                  67%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/6e013...
# 1  https://a0.muscache.com/im/pictures/user/4b75c...
# 2  https://a0.muscache.com/im/pictures/user/e5a15...
# 3  https://a0.muscache.com/im/pictures/user/6d332...
# 4  https://a0.muscache.com/im/users/24596747/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/6e013...                NaN
# 1  https://a0.muscache.com/im/pictures/user/4b75c...                NaN
# 2  https://a0.muscache.com/im/pictures/user/e5a15...                NaN
# 3  https://a0.muscache.com/im/pictures/user/6d332...                NaN
# 4  https://a0.muscache.com/im/users/24596747/prof...                NaN
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                  3.0                        3.0  ['email', 'phone']
# 1                  1.0                        1.0           ['phone']
# 2                  0.0                        0.0  ['email', 'phone']
# 3                  2.0                        2.0  ['email', 'phone']
# 4                  0.0                        0.0  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      f
# 2                    t                      f
# 3                    t                      t
# 4                    t                      t
#
#                          neighbourhood   neighbourhood_cleansed  \
# 0                                  NaN                   Cocotá
# 1                                  NaN  Freguesia (Jacarepaguá)
# 2  Jacarepaguá, Rio de Janeiro, Brazil                 Curicica
# 3               Rio de Janeiro, Brazil             Vila Militar
# 4                                  NaN             Del Castilho
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                           NaN -22.80630  -43.17788
# 1                           NaN -22.93633  -43.34907
# 2                           NaN -22.96253  -43.40291
# 3                           NaN -22.87969  -43.40361
# 4                           NaN -22.88168  -43.26803
#
#                        property_type        room_type  accommodates  \
# 0        Private room in rental unit     Private room             2
# 1                       Entire condo  Entire home/apt             4
# 2                 Entire rental unit  Entire home/apt             5
# 3                        Entire home  Entire home/apt             3
# 4  Private room in bed and breakfast     Private room             4
#
#    bathrooms bathrooms_text  bedrooms  beds  \
# 0        NaN         1 bath       1.0   1.0
# 1        NaN        2 baths       2.0   2.0
# 2        NaN         1 bath       2.0   5.0
# 3        NaN         1 bath       1.0   2.0
# 4        NaN      1.5 baths       2.0   3.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["TV", "Washer", "Kitchen", "Lock on bedroom d...  $150.00               1
# 1  ["Body soap", "Dedicated workspace", "Cleaning...  $450.00               7
# 2  ["Microwave", "Extra pillows and blankets", "F...  $350.00               2
# 3  ["Carbon monoxide alarm", "Cleaning before che...  $145.00               3
# 4  ["Body soap", "Dedicated workspace", "Backyard...  $180.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                       1                       1
# 1            1125                       7                       7
# 2             365                       2                       2
# 3             300                       3                       3
# 4              60                       2                       2
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     1.0
# 1                    1125                    1125                     7.0
# 2                     365                     365                     2.0
# 3                    1125                    1125                     3.0
# 4                      60                      60                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t               30
# 1                  1125.0               NaN                t                0
# 2                   365.0               NaN                t               29
# 3                  1125.0               NaN                t               19
# 4                    60.0               NaN                t               30
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               60               90               365            2022-06-20
# 1                0                0                52            2022-06-20
# 2               59               80               347            2022-06-20
# 3               49               79                79            2022-06-20
# 4               60               90               365            2022-06-20
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  0                      0                       0
# 1                  0                      0                       0
# 2                  9                      9                       0
# 3                 46                      1                       0
# 4                  0                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0          NaN         NaN                   NaN                     NaN
# 1          NaN         NaN                   NaN                     NaN
# 2   2021-10-31  2022-05-15                  5.00                    5.00
# 3   2016-08-10  2021-07-18                  4.78                    4.91
# 4          NaN         NaN                   NaN                     NaN
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                       5.00                   4.89
# 3                       4.89                   4.93
# 4                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                          NaN                     NaN                  NaN
# 2                         4.78                    4.78                 4.89
# 3                         4.87                    4.70                 4.57
# 4                          NaN                     NaN                  NaN
#
#    license instant_bookable  calculated_host_listings_count  \
# 0      NaN                f                               3
# 1      NaN                f                               1
# 2      NaN                f                               1
# 3      NaN                f                               1
# 4      NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             3
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0                NaN
# 2                                            0               1.16
# 3                                            0               0.64
# 4                                            0                NaN

# %%
# Verificar o tamanho, tipo e valores nulos dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24881 entries, 0 to 24880
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            24881 non-null  int64
#  1   listing_url                                   24881 non-null  object
#  2   scrape_id                                     24881 non-null  int64
#  3   last_scraped                                  24881 non-null  object
#  4   name                                          24860 non-null  object
#  5   description                                   23975 non-null  object
#  6   neighborhood_overview                         13370 non-null  object
#  7   picture_url                                   24881 non-null  object
#  8   host_id                                       24881 non-null  int64
#  9   host_url                                      24881 non-null  object
#  10  host_name                                     24764 non-null  object
#  11  host_since                                    24764 non-null  object
#  12  host_location                                 24700 non-null  object
#  13  host_about                                    12168 non-null  object
#  14  host_response_time                            19663 non-null  object
#  15  host_response_rate                            19663 non-null  object
#  16  host_acceptance_rate                          20071 non-null  object
#  17  host_is_superhost                             24764 non-null  object
#  18  host_thumbnail_url                            24764 non-null  object
#  19  host_picture_url                              24764 non-null  object
#  20  host_neighbourhood                            11859 non-null  object
#  21  host_listings_count                           24764 non-null  float64
#  22  host_total_listings_count                     24764 non-null  float64
#  23  host_verifications                            24881 non-null  object
#  24  host_has_profile_pic                          24764 non-null  object
#  25  host_identity_verified                        24764 non-null  object
#  26  neighbourhood                                 13370 non-null  object
#  27  neighbourhood_cleansed                        24881 non-null  object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      24881 non-null  float64
#  30  longitude                                     24881 non-null  float64
#  31  property_type                                 24881 non-null  object
#  32  room_type                                     24881 non-null  object
#  33  accommodates                                  24881 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                24828 non-null  object
#  36  bedrooms                                      23513 non-null  float64
#  37  beds                                          24630 non-null  float64
#  38  amenities                                     24881 non-null  object
#  39  price                                         24881 non-null  object
#  40  minimum_nights                                24881 non-null  int64
#  41  maximum_nights                                24881 non-null  int64
#  42  minimum_minimum_nights                        24881 non-null  int64
#  43  maximum_minimum_nights                        24881 non-null  int64
#  44  minimum_maximum_nights                        24881 non-null  int64
#  45  maximum_maximum_nights                        24881 non-null  int64
#  46  minimum_nights_avg_ntm                        24881 non-null  float64
#  47  maximum_nights_avg_ntm                        24881 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              24881 non-null  object
#  50  availability_30                               24881 non-null  int64
#  51  availability_60                               24881 non-null  int64
#  52  availability_90                               24881 non-null  int64
#  53  availability_365                              24881 non-null  int64
#  54  calendar_last_scraped                         24881 non-null  object
#  55  number_of_reviews                             24881 non-null  int64
#  56  number_of_reviews_ltm                         24881 non-null  int64
#  57  number_of_reviews_l30d                        24881 non-null  int64
#  58  first_review                                  17213 non-null  object
#  59  last_review                                   17213 non-null  object
#  60  review_scores_rating                          17213 non-null  float64
#  61  review_scores_accuracy                        16951 non-null  float64
#  62  review_scores_cleanliness                     16951 non-null  float64
#  63  review_scores_checkin                         16951 non-null  float64
#  64  review_scores_communication                   16951 non-null  float64
#  65  review_scores_location                        16950 non-null  float64
#  66  review_scores_value                           16951 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              24881 non-null  object
#  69  calculated_host_listings_count                24881 non-null  int64
#  70  calculated_host_listings_count_entire_homes   24881 non-null  int64
#  71  calculated_host_listings_count_private_rooms  24881 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   24881 non-null  int64
#  73  reviews_per_month                             17213 non-null  float64
# dtypes: float64(20), int64(21), object(33)
# memory usage: 14.0+ MB

# %%
# Verificar a porcentagem de valores nulos
pd.set_option("display.max_rows", None)
missing_much_values = (df.isnull().sum()/df.shape[0])
print(missing_much_values)
# Out:
# id                                              0.000000
# listing_url                                     0.000000
# scrape_id                                       0.000000
# last_scraped                                    0.000000
# name                                            0.000844
# description                                     0.036413
# neighborhood_overview                           0.462642
# picture_url                                     0.000000
# host_id                                         0.000000
# host_url                                        0.000000
# host_name                                       0.004702
# host_since                                      0.004702
# host_location                                   0.007275
# host_about                                      0.510952
# host_response_time                              0.209718
# host_response_rate                              0.209718
# host_acceptance_rate                            0.193320
# host_is_superhost                               0.004702
# host_thumbnail_url                              0.004702
# host_picture_url                                0.004702
# host_neighbourhood                              0.523371
# host_listings_count                             0.004702
# host_total_listings_count                       0.004702
# host_verifications                              0.000000
# host_has_profile_pic                            0.004702
# host_identity_verified                          0.004702
# neighbourhood                                   0.462642
# neighbourhood_cleansed                          0.000000
# neighbourhood_group_cleansed                    1.000000
# latitude                                        0.000000
# longitude                                       0.000000
# property_type                                   0.000000
# room_type                                       0.000000
# accommodates                                    0.000000
# bathrooms                                       1.000000
# bathrooms_text                                  0.002130
# bedrooms                                        0.054982
# beds                                            0.010088
# amenities                                       0.000000
# price                                           0.000000
# minimum_nights                                  0.000000
# maximum_nights                                  0.000000
# minimum_minimum_nights                          0.000000
# maximum_minimum_nights                          0.000000
# minimum_maximum_nights                          0.000000
# maximum_maximum_nights                          0.000000
# minimum_nights_avg_ntm                          0.000000
# maximum_nights_avg_ntm                          0.000000
# calendar_updated                                1.000000
# has_availability                                0.000000
# availability_30                                 0.000000
# availability_60                                 0.000000
# availability_90                                 0.000000
# availability_365                                0.000000
# calendar_last_scraped                           0.000000
# number_of_reviews                               0.000000
# number_of_reviews_ltm                           0.000000
# number_of_reviews_l30d                          0.000000
# first_review                                    0.308187
# last_review                                     0.308187
# review_scores_rating                            0.308187
# review_scores_accuracy                          0.318717
# review_scores_cleanliness                       0.318717
# review_scores_checkin                           0.318717
# review_scores_communication                     0.318717
# review_scores_location                          0.318757
# review_scores_value                             0.318717
# license                                         1.000000
# instant_bookable                                0.000000
# calculated_host_listings_count                  0.000000
# calculated_host_listings_count_entire_homes     0.000000
# calculated_host_listings_count_private_rooms    0.000000
# calculated_host_listings_count_shared_rooms     0.000000
# reviews_per_month                               0.308187
# dtype: float64

# %% [markdown]
# Pela quantidade de valores nulos, iremos excluir as colunas: "neighborhood_overview", "host_about", "host_neighbourhood", "neighbourhood", "bathrooms", "neighbourhood_group_cleansed", "calendar_updated", "license". Para nós, não faz sentido tentar trabalhar com essas colunas com muitos valores ausentes, isso implicaria em um viés altíssimo.
#
# Iremos eliminar também os metadados, que são apenas as colunas criadas a fim de obter um relacionamento com outras tabelas, como por exemplo, as colunas de "ID".
#
# Continuando nosso trabalho de seleção, vamos analisar coluna por coluna, para ver o que podemos descartar, pois, não vai gerar valor para nossa análise. Lembre-se, o objetivo é prever o preço do imóvel, portanto, precisamos de colunas informativas que nos leve a prever esse preço com assertividade.

# %%
# Analisar as entradas de coluna por coluna para tentar mapear o que pode ser relevante e o que não é relevante
for column in df.columns:
    values = df[column].head()
    print(values, '\n')
# Out:
# 0              15965441
# 1              47908784
# 2              52239613
# 3              10445855
# 4    565405043878669885
# Name: id, dtype: int64
#
# 0              https://www.airbnb.com/rooms/15965441
# 1              https://www.airbnb.com/rooms/47908784
# 2              https://www.airbnb.com/rooms/52239613
# 3              https://www.airbnb.com/rooms/10445855
# 4    https://www.airbnb.com/rooms/565405043878669885
# Name: listing_url, dtype: object
#
# 0    20220620202144
# 1    20220620202144
# 2    20220620202144
# 3    20220620202144
# 4    20220620202144
# Name: scrape_id, dtype: int64
#
# 0    2022-06-20
# 1    2022-06-20
# 2    2022-06-20
# 3    2022-06-20
# 4    2022-06-20
# Name: last_scraped, dtype: object
#
# 0    Quarto de casal com vista para a Baía de Guana...
# 1       Apartamento bem localizado, bonito e familiar!
# 2                Apartamento com varanda e linda vista
# 3                           Campo dos Afonsos, Sulacap
# 4      Pousada completa: 2 quartos com muita natureza!
# Name: name, dtype: object
#
# 0    Meu espaço é bom para casais, aventuras indivi...
# 1                                                  NaN
# 2    Condomínio com porteiro 24 horas , piscina, sa...
# 3    Casa com vista para as instalações do Parque  ...
# 4    Este lugar único e cheio de estilo é o cenário...
# Name: description, dtype: object
#
# 0                                                  NaN
# 1                                                  NaN
# 2    O condomínio fica em frente ao portão 2 do PRO...
# 3    Bairro suburbano, tranquilo, seguro, casas bem...
# 4                                                  NaN
# Name: neighborhood_overview, dtype: object
#
# 0    https://a0.muscache.com/pictures/76550464-7859...
# 1    https://a0.muscache.com/pictures/f44537ff-72f1...
# 2    https://a0.muscache.com/pictures/miso/Hosting-...
# 3    https://a0.muscache.com/pictures/0f42e026-0955...
# 4    https://a0.muscache.com/pictures/miso/Hosting-...
# Name: picture_url, dtype: object
#
# 0    103691209
# 1     83985216
# 2    422870631
# 3      1647571
# 4     24596747
# Name: host_id, dtype: int64
#
# 0    https://www.airbnb.com/users/show/103691209
# 1     https://www.airbnb.com/users/show/83985216
# 2    https://www.airbnb.com/users/show/422870631
# 3      https://www.airbnb.com/users/show/1647571
# 4     https://www.airbnb.com/users/show/24596747
# Name: host_url, dtype: object
#
# 0      José
# 1    Raquel
# 2     Fabio
# 3    Márcio
# 4     Júlio
# Name: host_name, dtype: object
#
# 0    2016-11-14
# 1    2016-07-15
# 2    2021-09-13
# 3    2012-01-24
# 4    2014-12-07
# Name: host_since, dtype: object
#
# 0    Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1    Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2        Petrópolis, State of Rio de Janeiro, Brazil
# 3    Rio de Janeiro, State of Rio de Janeiro, Brazil
# 4    Rio de Janeiro, State of Rio de Janeiro, Brazil
# Name: host_location, dtype: object
#
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Agora trabalhando com Experiencias do AirBnB. =-)
# 4    Sou  músico, professor, empreendedor, fotógraf...
# Name: host_about, dtype: object
#
# 0    within an hour
# 1      within a day
# 2      within a day
# 3    within an hour
# 4    within an hour
# Name: host_response_time, dtype: object
#
# 0     83%
# 1     50%
# 2    100%
# 3    100%
# 4    100%
# Name: host_response_rate, dtype: object
#
# 0      0%
# 1    100%
# 2     89%
# 3    100%
# 4     67%
# Name: host_acceptance_rate, dtype: object
#
# 0    f
# 1    f
# 2    f
# 3    f
# 4    f
# Name: host_is_superhost, dtype: object
#
# 0    https://a0.muscache.com/im/pictures/user/6e013...
# 1    https://a0.muscache.com/im/pictures/user/4b75c...
# 2    https://a0.muscache.com/im/pictures/user/e5a15...
# 3    https://a0.muscache.com/im/pictures/user/6d332...
# 4    https://a0.muscache.com/im/users/24596747/prof...
# Name: host_thumbnail_url, dtype: object
#
# 0    https://a0.muscache.com/im/pictures/user/6e013...
# 1    https://a0.muscache.com/im/pictures/user/4b75c...
# 2    https://a0.muscache.com/im/pictures/user/e5a15...
# 3    https://a0.muscache.com/im/pictures/user/6d332...
# 4    https://a0.muscache.com/im/users/24596747/prof...
# Name: host_picture_url, dtype: object
#
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: host_neighbourhood, dtype: object
#
# 0    3.0
# 1    1.0
# 2    0.0
# 3    2.0
# 4    0.0
# Name: host_listings_count, dtype: float64
#
# 0    3.0
# 1    1.0
# 2    0.0
# 3    2.0
# 4    0.0
# Name: host_total_listings_count, dtype: float64
#
# 0    ['email', 'phone']
# 1             ['phone']
# 2    ['email', 'phone']
# 3    ['email', 'phone']
# 4    ['email', 'phone']
# Name: host_verifications, dtype: object
#
# 0    t
# 1    t
# 2    t
# 3    t
# 4    t
# Name: host_has_profile_pic, dtype: object
#
# 0    t
# 1    f
# 2    f
# 3    t
# 4    t
# Name: host_identity_verified, dtype: object
#
# 0                                    NaN
# 1                                    NaN
# 2    Jacarepaguá, Rio de Janeiro, Brazil
# 3                 Rio de Janeiro, Brazil
# 4                                    NaN
# Name: neighbourhood, dtype: object
#
# 0                     Cocotá
# 1    Freguesia (Jacarepaguá)
# 2                   Curicica
# 3               Vila Militar
# 4               Del Castilho
# Name: neighbourhood_cleansed, dtype: object
#
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: neighbourhood_group_cleansed, dtype: float64
#
# 0   -22.80630
# 1   -22.93633
# 2   -22.96253
# 3   -22.87969
# 4   -22.88168
# Name: latitude, dtype: float64
#
# 0   -43.17788
# 1   -43.34907
# 2   -43.40291
# 3   -43.40361
# 4   -43.26803
# Name: longitude, dtype: float64
#
# 0          Private room in rental unit
# 1                         Entire condo
# 2                   Entire rental unit
# 3                          Entire home
# 4    Private room in bed and breakfast
# Name: property_type, dtype: object
#
# 0       Private room
# 1    Entire home/apt
# 2    Entire home/apt
# 3    Entire home/apt
# 4       Private room
# Name: room_type, dtype: object
#
# 0    2
# 1    4
# 2    5
# 3    3
# 4    4
# Name: accommodates, dtype: int64
#
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: bathrooms, dtype: float64
#
# 0       1 bath
# 1      2 baths
# 2       1 bath
# 3       1 bath
# 4    1.5 baths
# Name: bathrooms_text, dtype: object
#
# 0    1.0
# 1    2.0
# 2    2.0
# 3    1.0
# 4    2.0
# Name: bedrooms, dtype: float64
#
# 0    1.0
# 1    2.0
# 2    5.0
# 3    2.0
# 4    3.0
# Name: beds, dtype: float64
#
# 0    ["TV", "Washer", "Kitchen", "Lock on bedroom d...
# 1    ["Body soap", "Dedicated workspace", "Cleaning...
# 2    ["Microwave", "Extra pillows and blankets", "F...
# 3    ["Carbon monoxide alarm", "Cleaning before che...
# 4    ["Body soap", "Dedicated workspace", "Backyard...
# Name: amenities, dtype: object
#
# 0    $150.00
# 1    $450.00
# 2    $350.00
# 3    $145.00
# 4    $180.00
# Name: price, dtype: object
#
# 0    1
# 1    7
# 2    2
# 3    3
# 4    2
# Name: minimum_nights, dtype: int64
#
# 0    1125
# 1    1125
# 2     365
# 3     300
# 4      60
# Name: maximum_nights, dtype: int64
#
# 0    1
# 1    7
# 2    2
# 3    3
# 4    2
# Name: minimum_minimum_nights, dtype: int64
#
# 0    1
# 1    7
# 2    2
# 3    3
# 4    2
# Name: maximum_minimum_nights, dtype: int64
#
# 0    1125
# 1    1125
# 2     365
# 3    1125
# 4      60
# Name: minimum_maximum_nights, dtype: int64
#
# 0    1125
# 1    1125
# 2     365
# 3    1125
# 4      60
# Name: maximum_maximum_nights, dtype: int64
#
# 0    1.0
# 1    7.0
# 2    2.0
# 3    3.0
# 4    2.0
# Name: minimum_nights_avg_ntm, dtype: float64
#
# 0    1125.0
# 1    1125.0
# 2     365.0
# 3    1125.0
# 4      60.0
# Name: maximum_nights_avg_ntm, dtype: float64
#
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: calendar_updated, dtype: float64
#
# 0    t
# 1    t
# 2    t
# 3    t
# 4    t
# Name: has_availability, dtype: object
#
# 0    30
# 1     0
# 2    29
# 3    19
# 4    30
# Name: availability_30, dtype: int64
#
# 0    60
# 1     0
# 2    59
# 3    49
# 4    60
# Name: availability_60, dtype: int64
#
# 0    90
# 1     0
# 2    80
# 3    79
# 4    90
# Name: availability_90, dtype: int64
#
# 0    365
# 1     52
# 2    347
# 3     79
# 4    365
# Name: availability_365, dtype: int64
#
# 0    2022-06-20
# 1    2022-06-20
# 2    2022-06-20
# 3    2022-06-20
# 4    2022-06-20
# Name: calendar_last_scraped, dtype: object
#
# 0     0
# 1     0
# 2     9
# 3    46
# 4     0
# Name: number_of_reviews, dtype: int64
#
# 0    0
# 1    0
# 2    9
# 3    1
# 4    0
# Name: number_of_reviews_ltm, dtype: int64
#
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: number_of_reviews_l30d, dtype: int64
#
# 0           NaN
# 1           NaN
# 2    2021-10-31
# 3    2016-08-10
# 4           NaN
# Name: first_review, dtype: object
#
# 0           NaN
# 1           NaN
# 2    2022-05-15
# 3    2021-07-18
# 4           NaN
# Name: last_review, dtype: object
#
# 0     NaN
# 1     NaN
# 2    5.00
# 3    4.78
# 4     NaN
# Name: review_scores_rating, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    5.00
# 3    4.91
# 4     NaN
# Name: review_scores_accuracy, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    5.00
# 3    4.89
# 4     NaN
# Name: review_scores_cleanliness, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    4.89
# 3    4.93
# 4     NaN
# Name: review_scores_checkin, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    4.78
# 3    4.87
# 4     NaN
# Name: review_scores_communication, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    4.78
# 3    4.70
# 4     NaN
# Name: review_scores_location, dtype: float64
#
# 0     NaN
# 1     NaN
# 2    4.89
# 3    4.57
# 4     NaN
# Name: review_scores_value, dtype: float64
#
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: license, dtype: float64
#
# 0    f
# 1    f
# 2    f
# 3    f
# 4    f
# Name: instant_bookable, dtype: object
#
# 0    3
# 1    1
# 2    1
# 3    1
# 4    2
# Name: calculated_host_listings_count, dtype: int64
#
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: calculated_host_listings_count_entire_homes, dtype: int64
#
# 0    3
# 1    0
# 2    0
# 3    0
# 4    2
# Name: calculated_host_listings_count_private_rooms, dtype: int64
#
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: calculated_host_listings_count_shared_rooms, dtype: int64
#
# 0     NaN
# 1     NaN
# 2    1.16
# 3    0.64
# 4     NaN
# Name: reviews_per_month, dtype: float64

# %% [markdown]
# Baseado no nosso conhecimento de negócio, vamos listar as colunas que serão eliminadas, por certamente não agregarem valor na modelagem do problema em questão. São elas: "id", "listing_url", "scrape_id", "last_scraped", "name", "description", "picture_url", "host_id", "host_url", "host_name", "host_location", "host_thumbnail_url", "host_picture_url", "host_listings_count", "host_total_listings_count", "host_verifications", "neighbourhood_cleansed", "property_type", "amenities", "minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm", "calendar_last_scraped", "number_of_reviews_ltm", "number_of_reviews_l30d", "first_review", "last_review", "calculated_host_listings_count", "calculated_host_listings_count_entire_homes", "calculated_host_listings_count_private_rooms".

# %% [markdown]
# ## Pipeline ETL
#
# Nessa etapa, iremos fazer algumas transformações no dataset, para levarmos apenas o que realmente nos interessa para o projeto de ciência de dados.

# %%
# Criar uma cópia do conjunto de dados
df_clean = df.copy()

# %%
# 1. Remover as colunas que selecionamos
df_clean.drop(["neighborhood_overview", "host_about", "host_neighbourhood",
               "neighbourhood", "bathrooms", "neighbourhood_group_cleansed", 
               "calendar_updated", "license", "id", "listing_url", "scrape_id", 
               "last_scraped", "name", "description", "picture_url", "host_id", 
               "host_url", "host_name", "host_location", "host_thumbnail_url", 
               "host_picture_url", "host_listings_count", "host_total_listings_count", 
               "host_verifications", "neighbourhood_cleansed", "property_type", 
               "amenities", "minimum_minimum_nights", "maximum_minimum_nights", 
               "minimum_maximum_nights", "maximum_maximum_nights", "minimum_nights_avg_ntm", 
               "maximum_nights_avg_ntm", "calendar_last_scraped", "number_of_reviews_ltm", 
               "number_of_reviews_l30d", "first_review", "last_review", "calculated_host_listings_count", 
               "calculated_host_listings_count_entire_homes", "calculated_host_listings_count_private_rooms"], 
               axis=1, inplace=True)

# %% [markdown]
# Com essa 1a etapa finalizada, vamos agora apenas limpar algumas entradas de algumas colunas para que fiquem compatíveis com nosso projeto e podermos explorá-las mais profundamente quando chegarmos no pipeline de data science.

# %%
# 2. Passar a coluna "host_since" para datetime
df_clean.host_since = pd.to_datetime(df_clean.host_since, infer_datetime_format=True)

# %%
# 3. Elimar caracteres indesejados de algumas colunas
df_clean.host_response_rate = (df_clean.host_response_rate.str.replace('%', '').astype(float)) / 100 
df_clean.host_acceptance_rate = (df_clean.host_acceptance_rate.str.replace('%', '').astype(float)) / 100
df_clean.price = df_clean.price.str.replace('$', '').str.replace(',', '').astype(float)

# %%
# 4. Elimar caracteres indesejados da coluna "bathrooms_text"
mapping_dict_values = {
                      ' baths': '',
                      ' bath': '',
                      ' private bath': '',
                      ' private': '',
                      ' shared baths': '',
                      'Half-bath': '0.5',
                      'Shared half-bath': '0.5',
                      ' shared bath': '',
                      ' shared': '',
                      'Private half-bath': '0.5'
                      }
df_clean.bathrooms_text = df_clean.bathrooms_text.replace(mapping_dict_values, regex=True).astype(float)
df_clean.rename(columns={'bathrooms_text': 'bathrooms'}, inplace = True) # renomear coluna

# %% [markdown]
# Transformações feitas! Vamos dividir o conjunto de dados em treino e teste para alimentar o pipeline de data science.

# %% [markdown]
# ## Criando um conjunto de testes

# %%
# Separando o conjunto de dados em treino e teste
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df_clean, test_size = 0.2, random_state = 42)
train_set_size = len(train_set)
test_set_size = len(test_set)

print('Tamanho do conjunto de treino:', train_set_size)
print('Tamanho do conjunto de test:', test_set_size)
# Out:
# Tamanho do conjunto de treino: 19904
# Tamanho do conjunto de test: 4977

# %%
# # Exportar os arquivos de treino e teste para alimentar o pipeline de DS
# train_set.to_csv('/Users/Vitor/Desktop/InovaMed/Teste Modelo ML/train_set.csv', index=False)  
# test_set.to_csv('/Users/Vitor/Desktop/InovaMed/Teste Modelo ML/test_set.csv', index=False)
